# %% [markdown]
# ## Task 2: Mastodon API

# %% [markdown]
# ### Step 1: Create a Mastodon Application
# 1. Log-In to your Mastodon Server (eg. https://sciences.social/)
# 2. Under Preferences, click on Development
# 3. Click on New Application
# 4. Select functionalities i.e. read and write access the new application needs. For the purposes of this tutorial we will only be using 'read' functions.
# 5. Copy the 'Access Token' and store it securely

# %% [markdown]
# ### Required packages
# pip3 install httpx

# %%
import httpx
import getpass
from IPython.core import display
from dateutil import parser
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
# from mastodon import Mastodon
# ks3yuAI7JcF3VhhA8euLqN1MHvMrpyzd4l2HOs1udac

# %%
my_instance = "https://sciences.social/" # eg. https://mastodon.social/

# %%
token=getpass.getpass()
# Out:
# ········

# %%
client = httpx.Client(headers=dict(Authorization=f"Bearer {token}"))

# %%
res = client.get("{}/api/v1/accounts/verify_credentials".format(my_instance))

# %%
res.raise_for_status()
result = res.json()
result["id"], result["username"]
# Out:
# ('109334421628967389', 'anmolpanda')

# %%
usernames = [
    'https://mastodon.social/@RepShontelBrown'
]

# %%
def parse(result):
    result.raise_for_status()
    return result.json()

def get_date_from_string(date_str):
    return datetime.strptime(date_str, '%Y-%m-%dT%H:%M:%S.%fZ')

def get_toots_of_user(username):
    account = parse(client.get("https://sciences.social/api/v1/accounts/lookup?acct={}".format(username)))
    id_ = account['id']
    result = client.get("https://sciences.social/api/v1/accounts/{}/statuses?limit=40".format(id_))
    all_statuses = []
    statuses = parse(result)
    all_statuses.extend(statuses)
    while len(statuses) > 0:
        print(len(all_statuses))
        result = client.get("https://sciences.social/api/v1/accounts/{}/statuses?limit=40&max_id={}".format(id_, all_statuses[-1]['id']))
        statuses = parse(result)
        all_statuses.extend(statuses)
    return all_statuses


def get_id_from_date(date):
    # Code for this function taken from: 
    # https://shkspr.mobi/blog/2022/11/building-an-on-this-day-service-for-mastodon/
    return (int(date.timestamp()) << 16)*1000
    
def get_toots_of_user_between_dates(username, start_date, end_date):
    account = parse(client.get("https://sciences.social/api/v1/accounts/lookup?acct={}".format(username)))
    id_ = account['id']
    max_id = get_id_from_date(end_date)
    min_id = get_id_from_date(start_date)
    result = client.get("https://sciences.social/api/v1/accounts/{}/statuses?limit=40&max_id={}".format(id_, max_id))
    all_statuses = []
    statuses = parse(result)
    all_statuses.extend(statuses)
    while True:
        print(len(all_statuses))
        result = client.get("https://sciences.social/api/v1/accounts/{}/statuses?limit=40&max_id={}".format(id_, all_statuses[-1]['id']))
        statuses = parse(result)
        all_statuses.extend(statuses)
        earliest_date = get_date_from_string(all_statuses[-1]['created_at'])
        if earliest_date < start_date or len(statuses) == 0:
            break
    return all_statuses
    

# https://shkspr.mobi/blog/2022/11/building-an-on-this-day-service-for-mastodon/

def get_followers_of_user(server, username):
    account = parse(client.get("https://{}/api/v1/accounts/lookup?acct={}".format(server, username)))
    id_ = account['id']
    results = client.get("https://{}/api/v1/accounts/{}/followers?limit=80".format(server, id_))
    followers = parse(results)
    i=1
    print('Request: {}, Number of followers: {}'.format(i, len(followers)))
    while True:
        link = results.headers['link']
        if not 'next' in link:
            break
        next_url = link.split('<')[1].split('>')[0]
        results = client.get(next_url)
        followers.extend(parse(results))
        i+=1
        print('Request: {}, Number of followers: {}'.format(i, len(followers)))
        if i>20:
            break
    return followers
        
def get_accounts_followed_by_user(server, username):
    account = parse(client.get("https://{}/api/v1/accounts/lookup?acct={}".format(server, username)))
    id_ = account['id']
    results = client.get("https://{}/api/v1/accounts/{}/following?limit=80".format(server, id_))
    following = parse(results)
    i=1
    print('Request: {}, Number of accounts followed: {}'.format(i, len(following)))
    while True:
        link = results.headers['link']
        if not 'next' in link:
            break
        next_url = link.split('<')[1].split('>')[0]
        results = client.get(next_url)
        following.extend(parse(results))
        i+=1
        print('Request: {}, Number of accounts followed: {}'.format(i, len(following)))
    return following

def search_hashtag(hashtag):
    results = client.get("https://sciences.social/api/v1/timelines/tag/{}?limit=100".format(hashtag))
    statuses = parse(results)
    i=1
    print('Request: {}, Number of toots: {}'.format(i, len(statuses)))
    while True:
        link = results.headers['link']
        if not 'next' in link:
            break
        next_url = link.split('<')[1].split('>')[0]
        results = client.get(next_url)
        statuses.extend(parse(results))
        i+=1
        print('Request: {}, Number of toots: {}'.format(i, len(statuses)))
        if i > 50:
            break
    return statuses

def get_top_100_trending_hashtags(server):
    results = client.get("https://sciences.social/api/v1/timelines/tag/{}?limit=100".format(hashtag))

# %%
username = '@cfiesler@hci.social'
# toots = get_toots_of_user(username)

# %%
df_all_toots = pd.DataFrame(toots)
df_all_toots
# Out:
#                       id                created_at      in_reply_to_id  \
# 0     110489063647822039  2023-06-05T01:41:37.000Z  110488875560825729
# 1     110488764453590736  2023-06-05T00:25:28.000Z                None
# 2     110464390159842304  2023-05-31T17:06:48.000Z                None
# 3     110459966552111430  2023-05-30T22:21:47.000Z                None
# 4     110458292575777193  2023-05-30T15:16:05.000Z                None
# ...                  ...                       ...                 ...
# 1298  109257699985414271  2022-10-30T14:29:57.000Z  109251845340402435
# 1299  109257244402166230  2022-10-30T12:34:05.000Z                None
# 1300  109252899682302929  2022-10-29T18:09:10.000Z                None
# 1301  109251845340402435  2022-10-29T13:41:02.000Z  109248654456391898
# 1302  109248654456391898  2022-10-29T00:09:33.000Z                None
#
#      in_reply_to_account_id  sensitive spoiler_text visibility language  \
# 0        109327849920776618      False                  public       en
# 1                      None      False                  public       en
# 2                      None      False                  public       en
# 3                      None      False                  public       en
# 4                      None      False                  public     None
# ...                     ...        ...          ...        ...      ...
# 1298     109274913869213582      False                  public       en
# 1299                   None      False                  public       en
# 1300                   None      False                  public       en
# 1301     109274913869213582      False                  public       en
# 1302                   None      False                  public       en
#
#                                                     uri  \
# 0     https://hci.social/users/cfiesler/statuses/110...
# 1     https://hci.social/users/cfiesler/statuses/110...
# 2     https://hci.social/users/cfiesler/statuses/110...
# 3     https://hci.social/users/cfiesler/statuses/110...
# 4     https://hci.social/users/cfiesler/statuses/110...
# ...                                                 ...
# 1298  https://hci.social/users/cfiesler/statuses/109...
# 1299  https://hci.social/users/cfiesler/statuses/109...
# 1300  https://hci.social/users/cfiesler/statuses/109...
# 1301  https://hci.social/users/cfiesler/statuses/109...
# 1302  https://hci.social/users/cfiesler/statuses/109...
#
#                                                   url  ...  \
# 0     https://hci.social/@cfiesler/110489062456206741  ...
# 1     https://hci.social/@cfiesler/110488763013056688  ...
# 2     https://hci.social/@cfiesler/110464388864587691  ...
# 3     https://hci.social/@cfiesler/110459965088034460  ...
# 4                                                None  ...
# ...                                               ...  ...
# 1298  https://hci.social/@cfiesler/109257699997620515  ...
# 1299  https://hci.social/@cfiesler/109257244353278456  ...
# 1300  https://hci.social/@cfiesler/109252899659082452  ...
# 1301  https://hci.social/@cfiesler/109251845321040242  ...
# 1302  https://hci.social/@cfiesler/109248654422153709  ...
#
#                                                 content  filtered  \
# 0     <p><span class="h-card"><a href="https://hci.s...        []
# 1     <p>The very nice person who writes on cakes cl...        []
# 2     <p>found the bots in our Mastodon survey data</p>        []
# 3     <p>Your weekly reminder that I'm compiling a r...        []
# 4                                                              []
# ...                                                 ...       ...
# 1298  <p>for more on the challenges of migration, ch...        []
# 1299  <p>I saw a tiktok that played this scene from ...        []
# 1300  <p>an <a href="https://hci.social/tags/introdu...        []
# 1301  <p>Someone unrolled my bird thread about this ...        []
# 1302  <p>Have you packed your bags and relocated her...        []
#
#                                                  reblog  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4     {'id': '110441210490958628', 'created_at': '20...
# ...                                                 ...
# 1298                                               None
# 1299                                               None
# 1300                                               None
# 1301                                               None
# 1302                                               None
#
#                                                 account  \
# 0     {'id': '109274913869213582', 'username': 'cfie...
# 1     {'id': '109274913869213582', 'username': 'cfie...
# 2     {'id': '109274913869213582', 'username': 'cfie...
# 3     {'id': '109274913869213582', 'username': 'cfie...
# 4     {'id': '109274913869213582', 'username': 'cfie...
# ...                                                 ...
# 1298  {'id': '109274913869213582', 'username': 'cfie...
# 1299  {'id': '109274913869213582', 'username': 'cfie...
# 1300  {'id': '109274913869213582', 'username': 'cfie...
# 1301  {'id': '109274913869213582', 'username': 'cfie...
# 1302  {'id': '109274913869213582', 'username': 'cfie...
#
#                                       media_attachments  \
# 0                                                    []
# 1     [{'id': '110488764367663397', 'type': 'image',...
# 2     [{'id': '110464390053048894', 'type': 'image',...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1298                                                 []
# 1299  [{'id': '109314182725328826', 'type': 'image',...
# 1300                                                 []
# 1301                                                 []
# 1302  [{'id': '109274914040583914', 'type': 'image',...
#
#                                                mentions  \
# 0     [{'id': '109327849920776618', 'username': 'pg'...
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1298  [{'id': '109274914176958397', 'username': 'plu...
# 1299                                                 []
# 1300                                                 []
# 1301                                                 []
# 1302                                                 []
#
#                                                    tags  emojis  \
# 0                                                    []      []
# 1                                                    []      []
# 2                                                    []      []
# 3     [{'name': 'aiethicsnews', 'url': 'https://scie...      []
# 4                                                    []      []
# ...                                                 ...     ...
# 1298                                                 []      []
# 1299  [{'name': 'TheGoodPlace', 'url': 'https://scie...      []
# 1300  [{'name': 'Introduction', 'url': 'https://scie...      []
# 1301  [{'name': 'twittermigration', 'url': 'https://...      []
# 1302  [{'name': 'twittermigration', 'url': 'https://...      []
#
#                                                    card  poll
# 0                                                  None  None
# 1                                                  None  None
# 2                                                  None  None
# 3     {'url': 'https://docs.google.com/spreadsheets/...  None
# 4                                                  None  None
# ...                                                 ...   ...
# 1298  {'url': 'https://doctorow.medium.com/how-to-le...  None
# 1299                                               None  None
# 1300                                               None  None
# 1301  {'url': 'https://threadreaderapp.com/thread/15...  None
# 1302                                               None  None
#
# [1303 rows x 28 columns]

# %%
df_all_toots.drop_duplicates('id')
# Out:
#                       id                created_at      in_reply_to_id  \
# 0     110489063647822039  2023-06-05T01:41:37.000Z  110488875560825729
# 1     110488764453590736  2023-06-05T00:25:28.000Z                None
# 2     110464390159842304  2023-05-31T17:06:48.000Z                None
# 3     110459966552111430  2023-05-30T22:21:47.000Z                None
# 4     110458292575777193  2023-05-30T15:16:05.000Z                None
# ...                  ...                       ...                 ...
# 1298  109257699985414271  2022-10-30T14:29:57.000Z  109251845340402435
# 1299  109257244402166230  2022-10-30T12:34:05.000Z                None
# 1300  109252899682302929  2022-10-29T18:09:10.000Z                None
# 1301  109251845340402435  2022-10-29T13:41:02.000Z  109248654456391898
# 1302  109248654456391898  2022-10-29T00:09:33.000Z                None
#
#      in_reply_to_account_id  sensitive spoiler_text visibility language  \
# 0        109327849920776618      False                  public       en
# 1                      None      False                  public       en
# 2                      None      False                  public       en
# 3                      None      False                  public       en
# 4                      None      False                  public     None
# ...                     ...        ...          ...        ...      ...
# 1298     109274913869213582      False                  public       en
# 1299                   None      False                  public       en
# 1300                   None      False                  public       en
# 1301     109274913869213582      False                  public       en
# 1302                   None      False                  public       en
#
#                                                     uri  \
# 0     https://hci.social/users/cfiesler/statuses/110...
# 1     https://hci.social/users/cfiesler/statuses/110...
# 2     https://hci.social/users/cfiesler/statuses/110...
# 3     https://hci.social/users/cfiesler/statuses/110...
# 4     https://hci.social/users/cfiesler/statuses/110...
# ...                                                 ...
# 1298  https://hci.social/users/cfiesler/statuses/109...
# 1299  https://hci.social/users/cfiesler/statuses/109...
# 1300  https://hci.social/users/cfiesler/statuses/109...
# 1301  https://hci.social/users/cfiesler/statuses/109...
# 1302  https://hci.social/users/cfiesler/statuses/109...
#
#                                                   url  ...  \
# 0     https://hci.social/@cfiesler/110489062456206741  ...
# 1     https://hci.social/@cfiesler/110488763013056688  ...
# 2     https://hci.social/@cfiesler/110464388864587691  ...
# 3     https://hci.social/@cfiesler/110459965088034460  ...
# 4                                                None  ...
# ...                                               ...  ...
# 1298  https://hci.social/@cfiesler/109257699997620515  ...
# 1299  https://hci.social/@cfiesler/109257244353278456  ...
# 1300  https://hci.social/@cfiesler/109252899659082452  ...
# 1301  https://hci.social/@cfiesler/109251845321040242  ...
# 1302  https://hci.social/@cfiesler/109248654422153709  ...
#
#                                                 content  filtered  \
# 0     <p><span class="h-card"><a href="https://hci.s...        []
# 1     <p>The very nice person who writes on cakes cl...        []
# 2     <p>found the bots in our Mastodon survey data</p>        []
# 3     <p>Your weekly reminder that I'm compiling a r...        []
# 4                                                              []
# ...                                                 ...       ...
# 1298  <p>for more on the challenges of migration, ch...        []
# 1299  <p>I saw a tiktok that played this scene from ...        []
# 1300  <p>an <a href="https://hci.social/tags/introdu...        []
# 1301  <p>Someone unrolled my bird thread about this ...        []
# 1302  <p>Have you packed your bags and relocated her...        []
#
#                                                  reblog  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4     {'id': '110441210490958628', 'created_at': '20...
# ...                                                 ...
# 1298                                               None
# 1299                                               None
# 1300                                               None
# 1301                                               None
# 1302                                               None
#
#                                                 account  \
# 0     {'id': '109274913869213582', 'username': 'cfie...
# 1     {'id': '109274913869213582', 'username': 'cfie...
# 2     {'id': '109274913869213582', 'username': 'cfie...
# 3     {'id': '109274913869213582', 'username': 'cfie...
# 4     {'id': '109274913869213582', 'username': 'cfie...
# ...                                                 ...
# 1298  {'id': '109274913869213582', 'username': 'cfie...
# 1299  {'id': '109274913869213582', 'username': 'cfie...
# 1300  {'id': '109274913869213582', 'username': 'cfie...
# 1301  {'id': '109274913869213582', 'username': 'cfie...
# 1302  {'id': '109274913869213582', 'username': 'cfie...
#
#                                       media_attachments  \
# 0                                                    []
# 1     [{'id': '110488764367663397', 'type': 'image',...
# 2     [{'id': '110464390053048894', 'type': 'image',...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1298                                                 []
# 1299  [{'id': '109314182725328826', 'type': 'image',...
# 1300                                                 []
# 1301                                                 []
# 1302  [{'id': '109274914040583914', 'type': 'image',...
#
#                                                mentions  \
# 0     [{'id': '109327849920776618', 'username': 'pg'...
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1298  [{'id': '109274914176958397', 'username': 'plu...
# 1299                                                 []
# 1300                                                 []
# 1301                                                 []
# 1302                                                 []
#
#                                                    tags  emojis  \
# 0                                                    []      []
# 1                                                    []      []
# 2                                                    []      []
# 3     [{'name': 'aiethicsnews', 'url': 'https://scie...      []
# 4                                                    []      []
# ...                                                 ...     ...
# 1298                                                 []      []
# 1299  [{'name': 'TheGoodPlace', 'url': 'https://scie...      []
# 1300  [{'name': 'Introduction', 'url': 'https://scie...      []
# 1301  [{'name': 'twittermigration', 'url': 'https://...      []
# 1302  [{'name': 'twittermigration', 'url': 'https://...      []
#
#                                                    card  poll
# 0                                                  None  None
# 1                                                  None  None
# 2                                                  None  None
# 3     {'url': 'https://docs.google.com/spreadsheets/...  None
# 4                                                  None  None
# ...                                                 ...   ...
# 1298  {'url': 'https://doctorow.medium.com/how-to-le...  None
# 1299                                               None  None
# 1300                                               None  None
# 1301  {'url': 'https://threadreaderapp.com/thread/15...  None
# 1302                                               None  None
#
# [1303 rows x 28 columns]

# %%
start_date = datetime(2023,1,1)
end_date = datetime(2023,1,31)
select_toots = get_toots_of_user_between_dates(username, start_date, end_date)
# Out:
# 40
# 80

# %%
df_select_toots = pd.DataFrame(select_toots)
df_select_toots['date'] = df_select_toots.created_at.apply(get_date_from_string)
df_select_toots
# Out:
#                      id                created_at      in_reply_to_id  \
# 0    109770038507233024  2023-01-29T02:04:07.000Z  109769457419150796
# 1    109767294528667392  2023-01-28T14:26:17.000Z                None
# 2    109767289380133727  2023-01-28T14:25:00.000Z  109767285439907920
# 3    109767275078337902  2023-01-28T14:21:22.000Z  109767254462195509
# 4    109767270504194919  2023-01-28T14:20:12.000Z  109767260096965253
# ..                  ...                       ...                 ...
# 115  109592748118269341  2022-12-28T18:36:31.000Z                None
# 116  109591446449195947  2022-12-28T13:05:59.000Z  109589611839070291
# 117  109588898669387959  2022-12-28T02:18:04.000Z  109588885964559566
# 118  109588872872861646  2022-12-28T02:11:32.000Z  109588814391130555
# 119  109588802151601878  2022-12-28T01:53:23.000Z                None
#
#     in_reply_to_account_id  sensitive spoiler_text visibility language  \
# 0       109280246048887299      False                unlisted       en
# 1                     None      False                  public     None
# 2       109410675112416670      False                  public       en
# 3       109270991407203918      False                  public       en
# 4       109472665357221096      False                  public       en
# ..                     ...        ...          ...        ...      ...
# 115                   None      False                  public       en
# 116     109286119114006837      False                  public       en
# 117     109304693533446697      False                unlisted       en
# 118     109304693533446697      False                unlisted       en
# 119                   None      False                  public       en
#
#                                                    uri  \
# 0    https://hci.social/users/cfiesler/statuses/109...
# 1    https://hci.social/users/cfiesler/statuses/109...
# 2    https://hci.social/users/cfiesler/statuses/109...
# 3    https://hci.social/users/cfiesler/statuses/109...
# 4    https://hci.social/users/cfiesler/statuses/109...
# ..                                                 ...
# 115  https://hci.social/users/cfiesler/statuses/109...
# 116  https://hci.social/users/cfiesler/statuses/109...
# 117  https://hci.social/users/cfiesler/statuses/109...
# 118  https://hci.social/users/cfiesler/statuses/109...
# 119  https://hci.social/users/cfiesler/statuses/109...
#
#                                                  url  ...  filtered  \
# 0    https://hci.social/@cfiesler/109770037501727567  ...        []
# 1                                               None  ...        []
# 2    https://hci.social/@cfiesler/109767288445160507  ...        []
# 3    https://hci.social/@cfiesler/109767274140614999  ...        []
# 4    https://hci.social/@cfiesler/109767269580244595  ...        []
# ..                                               ...  ...       ...
# 115  https://hci.social/@cfiesler/109592745813118112  ...        []
# 116  https://hci.social/@cfiesler/109591446103451722  ...        []
# 117  https://hci.social/@cfiesler/109588898439808139  ...        []
# 118  https://hci.social/@cfiesler/109588872717748128  ...        []
# 119  https://hci.social/@cfiesler/109588801346818908  ...        []
#
#                                                 reblog  \
# 0                                                 None
# 1    {'id': '109740145386169954', 'created_at': '20...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 115                                               None
# 116                                               None
# 117                                               None
# 118                                               None
# 119                                               None
#
#                                                account media_attachments  \
# 0    {'id': '109274913869213582', 'username': 'cfie...                []
# 1    {'id': '109274913869213582', 'username': 'cfie...                []
# 2    {'id': '109274913869213582', 'username': 'cfie...                []
# 3    {'id': '109274913869213582', 'username': 'cfie...                []
# 4    {'id': '109274913869213582', 'username': 'cfie...                []
# ..                                                 ...               ...
# 115  {'id': '109274913869213582', 'username': 'cfie...                []
# 116  {'id': '109274913869213582', 'username': 'cfie...                []
# 117  {'id': '109274913869213582', 'username': 'cfie...                []
# 118  {'id': '109274913869213582', 'username': 'cfie...                []
# 119  {'id': '109274913869213582', 'username': 'cfie...                []
#
#                                               mentions  tags  emojis  \
# 0    [{'id': '109280246048887299', 'username': 'asb...    []      []
# 1                                                   []    []      []
# 2    [{'id': '109410675112416670', 'username': 'spa...    []      []
# 3    [{'id': '109270991407203918', 'username': 'jia...    []      []
# 4    [{'id': '109472665357221096', 'username': 'kil...    []      []
# ..                                                 ...   ...     ...
# 115                                                 []    []      []
# 116  [{'id': '109286119114006837', 'username': 'hyp...    []      []
# 117  [{'id': '109304693533446697', 'username': 'rya...    []      []
# 118  [{'id': '109304693533446697', 'username': 'rya...    []      []
# 119                                                 []    []      []
#
#                                                   card  poll  \
# 0                                                 None  None
# 1                                                 None  None
# 2                                                 None  None
# 3                                                 None  None
# 4                                                 None  None
# ..                                                 ...   ...
# 115  {'url': 'https://www.washingtonpost.com/dc-md-...  None
# 116                                               None  None
# 117                                               None  None
# 118                                               None  None
# 119                                               None  None
#
#                    date
# 0   2023-01-29 02:04:07
# 1   2023-01-28 14:26:17
# 2   2023-01-28 14:25:00
# 3   2023-01-28 14:21:22
# 4   2023-01-28 14:20:12
# ..                  ...
# 115 2022-12-28 18:36:31
# 116 2022-12-28 13:05:59
# 117 2022-12-28 02:18:04
# 118 2022-12-28 02:11:32
# 119 2022-12-28 01:53:23
#
# [120 rows x 29 columns]

# %%
df_all_toots['date'] = df_all_toots['created_at'].apply(get_date_from_string)

# %%
df_all_toots[(df_all_toots.date >start_date)&(df_all_toots.date < end_date)].date.describe()
# Out:
# /tmp/ipykernel_2680/4260483181.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_all_toots[(df_all_toots.date >start_date)&(df_all_toots.date < end_date)].date.describe()
# count                      97
# unique                     97
# top       2023-01-29 02:04:07
# freq                        1
# first     2023-01-01 13:35:48
# last      2023-01-29 02:04:07
# Name: date, dtype: object

# %%
df_select_toots.date.describe()
# Out:
# /tmp/ipykernel_2680/1479911692.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_select_toots.date.describe()
# count                     120
# unique                    120
# top       2023-01-29 02:04:07
# freq                        1
# first     2022-12-28 01:53:23
# last      2023-01-29 02:04:07
# Name: date, dtype: object

# %%
# Out:
# datetime.datetime(2023, 1, 10, 17, 4, 20)

# %%
username = '@QasimRashid@mastodon.social'
server = 'hci.social'
followers = get_followers_of_user(server, username)
len(followers)

# %%
df_followers = pd.DataFrame(followers)
df_followers.username.nunique()

# %%
df_following = pd.DataFrame(get_accounts_followed_by_user(server, username))
df_following

# %%
end_date = datetime(2023,1,1)
end_date.timestamp()
# Out:
# 1672524000.0

# %%
bit_shifted = 110310925158294068 >> 16
bit_shifted
# Out:
# 1683211138279

# %%
datetime.fromtimestamp(1683211138279/1000)
# datetime.datetime(2022, 11, 11, 18, 16, 4, 630000)
# Out:
# datetime.datetime(2023, 5, 4, 17, 38, 58, 279000)

# %%
(int(end_date.timestamp()) << 16)*1000
# Out:
# 109610532864000000

# %%
(int( end_date.timestamp()) << 16)*1000
# Out:
# 109610532864000000

# %%
result = parse(client.get("https://sciences.social/api/v1/accounts/109334421628967389"))
result["username"]

# %%
statuses = search_hashtag('democrats')

# %%
len(statuses)

# %%
df_statuses = pd.DataFrame(statuses)
df_statuses.columns
